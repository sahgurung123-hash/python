# %%
#1.	 Write a program to count and display the number of capital letters in a given string.
input_string = input("Enter a string: ")
capital_count = 0
capital_letters = []

for char in input_string:
    if char.isupper():
        capital_count += 1
        capital_letters.append(char)

print(f"Number of capital letters: {capital_count}")
print(f"Capital letters found: {capital_letters}")
# Out:
# Number of capital letters: 5
# Capital letters found: ['D', 'S', 'F', 'A', 'S']

# %%
#2.	Count total number of vowels in a given string.
input_string = input("Enter a string: ")
vowel_count = 0
vowels = "aeiouAEIOU"

for char in input_string:
    if char in vowels:
        vowel_count += 1

print(f"Total number of vowels: {vowel_count}")
# Out:
# Total number of vowels: 0

# %%
#3.	Input a sentence and print words in separate lines.
sentence = input("Enter a sentence: ")
words = sentence.split()
for word in words:
    print(word)
# Out:
# afd
# fadf
# dag

# %%
#4.	WAP to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String traversal will take place from left to right, not from right to left. 
#Sample Input 
#ABCDCDC 
#CDC 
#Sample Output 
#2
main_string = input("Enter the main string: ")
substring = input("Enter the substring to search for: ")    
count = 0
for i in range(len(main_string) - len(substring) + 1):
    if main_string[i:i+len(substring)] == substring:
        count += 1
print(f"The substring '{substring}' occurs {count} times in the main string.")
# Out:
# The substring 'adsdfaefa' occurs 0 times in the main string.

# %%
#5.	Given a string containing both upper and lower-case alphabets. Write a Python program to count the number of occurrences of each alphabet (case insensitive) and display the same. 
#Sample Input 
#ABaBCbGc 
#Sample Output 
#2A 
#3B 
#2C 
#1G 
input_string = input("Enter a string: ")
alphabet_count = {} 
for char in input_string:
    char = char.upper()  # Convert to uppercase for case insensitivity
    alphabet_count[char] = alphabet_count.get(char, 0) + 1

for alphabet, count in sorted(alphabet_count.items()):
    print(f"{count}{alphabet}")
# Out:
# 1
# 1D
# 4F
# 2G
# 5H
# 2J
# 2K

# %%
#6.	Program to count the number of unique words in a given sentence using sets. 
sentence = input("Enter a sentence: ")
words = sentence.split()
unique_words = set(words)
print(f"Number of unique words: {len(unique_words)}")
print("Unique words:", unique_words)
# Out:
# Number of unique words: 1
# Unique words: {'kl;ghkj;k'}

# %%
#7.	Create 2 sets s1 and s2 of n fruits each by taking input from user and find: 
#a.	Fruits which are in both sets s1 and s2 
#b.	Fruits only in s1 but not in s2 
#c.	Count of all fruits from s1 and s2 

n = int(input("Enter the number of fruits for each set: "))
s1 = set()
s2 = set()
print("Enter fruits for set s1:")
for _ in range(n):
    fruit = input("Fruit: ")
    s1.add(fruit)
print("Enter fruits for set s2:")
for _ in range(n):
    fruit = input("Fruit: ")
    s2.add(fruit)   
common_fruits = s1.intersection(s2)
fruits_only_in_s1 = s1.difference(s2)
total_fruits_count = len(s1.union(s2))
print(f"Fruits in both sets s1 and s2: {common_fruits}")    
print(f"Fruits only in s1 but not in s2: {fruits_only_in_s1}")
print(f"Count of all fruits from s1 and s2: {total_fruits_count}")
# Out:
# Enter fruits for set s1:
# Enter fruits for set s2:
# Fruits in both sets s1 and s2: set()
# Fruits only in s1 but not in s2: {'asf', 'hfdg', 'gfd', 'sfdg', 'djtjf'}
# Count of all fruits from s1 and s2: 10

# %%
#8.	Take two sets and apply various set operations on them: 
#S1 = {Red, yellow, orange, blue} 
#S2 = {violet, blue, purple}

S1 = {"Red", "yellow", "orange", "blue"}
S2 = {"violet", "blue", "purple"}
print(f"Union of S1 and S2: {S1.union(S2)}")
print(f"Intersection of S1 and S2: {S1.intersection(S2)}")
print(f"Difference of S1 and S2 (S1 - S2): {S1.difference(S2)}")
print(f"Difference of S1 and S2 (S2 - S1): {S2.difference(S1)}")
print(f"Symmetric difference of S1 and S2: {S1.symmetric_difference(S2)}")
# Out:
# Union of S1 and S2: {'Red', 'blue', 'orange', 'yellow', 'purple', 'violet'}
# Intersection of S1 and S2: {'blue'}
# Difference of S1 and S2 (S1 - S2): {'yellow', 'Red', 'orange'}
# Difference of S1 and S2 (S2 - S1): {'violet', 'purple'}
# Symmetric difference of S1 and S2: {'Red', 'orange', 'yellow', 'violet', 'purple'}
