# %%
1.	Install Python and understand difference between scripting and interactive modes in IDLE. 

= difference between scripting and interactive modes in IDLE is
🔹 Interactive Mode
*You type code directly in the Python Shell.
*Python executes immediately after pressing Enter.
*Good for quick checks.

🔹 Scripting Mode
*You write code in the IDLE editor and save as .py.
*Run using F5 or Run → Run Module.
*Python executes the whole file.

# %%
#2.	Write Python programs to print strings in the given manner: 
#a)   Hello Everyone !!! 
print("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %%
#b)   Hello 
#      World 
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
#(c)Hello 
#              World 
print("Hello")
print("              World")
# Out:
# Hello
#               World

# %%
#d) ‘ Rohit’ s date of birth is 12\05\1999’ 
print("‘ Rohit’ s date of birth is 12\\05\\1999’ ")
# Out:
# ‘ Rohit’ s date of birth is 12\05\1999’

# %%
#Q3 Declare a string variable called x and assign it the value “Hello”. Print out the value of x 

x = "Hello"
print(x)
# Out:
# Hello

# %%
#4.	Take different data types and print values using print function.
integer_value = 42
float_value = 3.14159
string_value = "Hello, World!"
boolean_value = True

print("Integer value:", integer_value)
print("Float value:", float_value)
print("String value:", string_value)
print("Boolean value:", boolean_value)
# Out:
# Integer value: 42
# Float value: 3.14159
# String value: Hello, World!
# Boolean value: True

# %%
#5.	Take two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together. 
a="sahil"
b="gurung"
print(a+" "+b)
# Out:
# sahil gurung

# %%
#6.	Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last name.   
first_name = "Sahil"
Last_name = "Gurung"
nickname = "Sahil"
print(first_name +"("+nickname+") "+Last_name)
# Out:
# Sahil(Sahil) Gurung

# %%
#7.	Declare and assign values to suitable variables and print in the following way:
#NAME: NIKUNJ BANSAL   
#SAP ID: 500069944 
#DATE OF BIRTH: 13 Oct 1999 
#ADDRESS: UPES Bidholi Campus 
#Pincode: 248007 
#Programme: AI & ML                                                                                       
#Semester: 2

a="NAME: NIKUNJ BANSAL"
b="SAP ID: 500069944"
c="DATE OF BIRTH: 13 Oct 1999"
d="ADDRESS: UPES Bidholi Campus"
e="Pincode: 248007"
f="Programme: AI & ML"
g="Semester: 2"
print(a,b,c,d,e,f,g,sep="\n")
# Out:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES Bidholi Campus
# Pincode: 248007
# Programme: AI & ML
# Semester: 2
